# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import requests
import datetime as dt
import time 
from datetime import datetime
import datetime

# %% [markdown]
# #1.1.1 Cabled Axial Seamount Axial Base Shallow Profiler Mooring - Shallow Profiler
#
# 2019-07-06  -  2019-07-07
#
# ASS=Axial summer shallow     z=depth [m]; z=h=P/(rho*g)

# %%
ASS=pd.read_csv("Axial_summer_shallow.csv")
A1=ASS.seawater_pressure
AA1=ASS.time
B1=ASS.seawater_temperature
C1=ASS.practical_salinity
z1=(A1*10000)/(1000*9.81)

# %%
ssp1=1449.2+(4.6*B1)-(0.055*B1**2)+(0.00029*B1**3)+(1.34-0.01*B1)*(C1-35)+(0.016*z1)
s1=max(ssp1)
print("the max speed of sound is ",s1, "m/s")
x1=ssp1
y1=z1
# Out:
# the max speed of sound is  1507.3063881255669 m/s

# %%
#plot the data
Avg2=np.polyfit(z2,ssp2,6)
Avg_ssp2=np.poly1d(Avg2)(z2)
plt.plot(ssp2,z2)
plt.plot(Avg_ssp2,z2)
plt.gca().invert_yaxis()

plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('Axial Winter Shallow')

plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time1=[]
for i in range(len(AA1)):
 time1.append(ntp_seconds_to_datetime(AA1[i]))

plt.plot(time1,z1)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Axial Summer Shallow')
plt.xticks(rotation=50)


#counting the bumber of dives
def getnumberofDives(z1):
    bottom=max(z1)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z1)):
        
        if(z1[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z1[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N1=getnumberofDives(z1)
print("The number of dives for Axial Base Summer Shallow is = ",N1)
# Out:
# The number of dives for Axial Base Summer Shallow is =  9

# %%
plt.plot(time1,ssp1)
plt.ylabel('ssp [m/s]')
plt.xlabel('time [s]')
plt.title('Axial Summer Shallow')
plt.xticks(rotation=50)
# Out:
# (array([737246.   , 737246.125, 737246.25 , 737246.375, 737246.5  ,
#         737246.625, 737246.75 , 737246.875, 737247.   ]),
#  <a list of 9 Text xticklabel objects>)

# %%
plt.plot(time1,ssp1)

plt.ylabel('ssp [m/s]')
plt.xlabel('Time')
plt.title('Axial Summer Shallow')
plt.xticks(rotation=50)
# Out:
# (array([737246.   , 737246.125, 737246.25 , 737246.375, 737246.5  ,
#         737246.625, 737246.75 , 737246.875, 737247.   ]),
#  <a list of 9 Text xticklabel objects>)

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# #1.1.2 Cabled Axial Seamount Axial Base Shallow Profiler Mooring - 200m Platform
#
# 2019-01-06 -  2019-01-07
#
# AWS= Axial winter shallow

# %%
AWS=pd.read_csv("Axial_winter_shallow.csv")
A2=AWS.seawater_pressure
AA2=AWS.time
B2=AWS.seawater_temperature
C2=AWS.practical_salinity
# the depth
z2=(A2*10000)/(1000*9.81)

# %%
ssp2=1449.2+(4.6*B2)-(0.055*B2**2)+(0.00029*B2**3)+(1.34-0.01*B2)*(C2-35)+(0.016*z2)
x2=ssp2
y2=z2
s2=max(ssp2)
print("the max speed of sound is ",s2, "m/s")
# Out:
# the max speed of sound is  1493.4774261282842 m/s

# %%
Avg2=np.polyfit(z2,ssp2,10)
Avg_ssp2=np.poly1d(Avg2)(z2)
plt.plot(ssp2,z2)
plt.plot(Avg_ssp2,z2)
plt.gca().invert_yaxis()

plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('Axial Winter Shallow')

plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time2=[]
for i in range(len(AA2)):
 time2.append(ntp_seconds_to_datetime(AA2[i]))

plt.plot(time2,z2)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Axial Winter Shallow')
plt.xticks(rotation=50)



#counting the bumber of dives
def getnumberofDives(z2):
    bottom=max(z2)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z2)):
        
        if(z2[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z2[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N2=getnumberofDives(z2)
print("The number of dives for Axial Base Winter Shallow is = ",N2)
# Out:
# The number of dives for Axial Base Winter Shallow is =  9

# %%
plt.plot(time2,ssp2)
plt.ylabel('ssp [m/s]')
plt.xlabel('time')
plt.title('Axial Winter Shallow')
plt.xticks(rotation=50)
# Out:
# (array([737430.   , 737430.125, 737430.25 , 737430.375, 737430.5  ,
#         737430.625, 737430.75 , 737430.875, 737431.   ]),
#  <a list of 9 Text xticklabel objects>)

# %% [markdown]
# =====================================================================================================

# %% [markdown]
# #1.2.1 Cabled Axial Seamount Axial Base Deep Profiler Mooring - Wire-Following Profiler
#
# 2019-07-06   -  2019-07-07
#
# ASD=Axial summer deep

# %%
ASD=pd.read_csv("Axial_summer_deep.csv")
A3=ASD.pressure
AA3=ASD.time
B3=ASD.temp
C3=ASD.practical_salinity
z3=(A3*10000)/(1000*9.81)

# %%
ssp3=1449.2+(4.6*B3)-(0.055*B3**2)+(0.00029*B3**3)+(1.34-0.01*B3)*(C3-35)+(0.016*z3)
x3=ssp3
y3=z3
s3=max(ssp3)
print("the max speed of sound is ",s3, "m/s")
# Out:
# the max speed of sound is  1499.868054806177 m/s

# %%
Avg3=np.polyfit(z3,ssp3,10)
Avg_ssp3=np.poly1d(Avg3)(z3)
plt.plot(ssp3,z3)
plt.plot(Avg_ssp3,z3)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('time [s]')
plt.title('Axial Summer Deep')
plt.gca().legend(('ssp [m/s]','ssp average [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time3=[]
for i in range(len(AA3)):
 time3.append(ntp_seconds_to_datetime(AA3[i]))

plt.plot(time3,z3)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Axial Summer Deep')
plt.xticks(rotation=50)



#counting the bumber of dives
def getnumberofDives(z3):
    bottom=max(z3)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z3)):
        
        if(z3[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z3[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N3=getnumberofDives(z3)
print("The number of dives for Axial Base Summer Deep is = ",N3)
# Out:
# The number of dives for Axial Base Summer Deep is =  2

# %%
plt.plot(time3,ssp3)

plt.ylabel('ssp[m/s]')
plt.xlabel('Time')
plt.title('Axial Summer Deep')
plt.xticks(rotation=50)
# Out:
# (array([737246.875, 737247.   , 737247.125, 737247.25 , 737247.375,
#         737247.5  , 737247.625, 737247.75 ]),
#  <a list of 8 Text xticklabel objects>)

# %% [markdown]
# ========================================================================================

# %% [markdown]
# #1.2.2 Cabled Axial Seamount Axial Base Deep Profiler Mooring - Wire-Following Profiler
#
# 2019-01-06 -  2019-01-07
#
# AWD= Axial winter deep

# %%
AWD=pd.read_csv("Axial_winter_deep.csv")
A4=AWD.pressure
AA4=AWD.time
B4=AWD.temp
C4=AWD.practical_salinity
z4=(A4*10000)/(1000*9.81)

# %%
ssp4=1449.2+(4.6*B4)-(0.055*B4**2)+(0.00029*B4**3)+(1.34-0.01*B4)*(C4-35)+(0.016*z4)
x4=ssp4
y4=z4
s4=max(ssp4)
print("the max speed of sound is ",s4, "m/s")
# Out:
# the max speed of sound is  1500.0062497840217 m/s

# %%
Avg4=np.polyfit(z4,ssp4,10)
Avg_ssp4=np.poly1d(Avg4)(z4)
plt.plot(ssp4,z4)
plt.plot(Avg_ssp4,z4)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('Axial Winter Deep')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# UTC to PST
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time4=[]
for i in range(len(AA4)):
 time4.append(ntp_seconds_to_datetime(AA4[i]))

plt.plot(time4,z4)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Axial Winter Deep')
plt.xticks(rotation=50)


#counting the bumber of dives
def getnumberofDives(z4):
    bottom=max(z4)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z4)):
        
        if(z4[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z4[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N4=getnumberofDives(z4)
print("The number of dives for Axial Base winter Deep is = ",N4)
# Out:
# The number of dives for Axial Base winter Deep is =  2

# %%
plt.plot(time4,ssp4)
plt.ylabel('ssp [m/s]')
plt.xlabel('time [s]')
plt.title('Axial Winter Deep)')
plt.xticks(rotation=50)
# Out:
# (array([737431.        , 737431.08333333, 737431.16666667, 737431.25      ,
#         737431.33333333, 737431.41666667, 737431.5       , 737431.58333333,
#         737431.66666667, 737431.75      ]),
#  <a list of 10 Text xticklabel objects>)

# %%
# Out:
# The number of dives for Axial Base winter Deep is =  2

# %% [markdown]
# =====================================================================================================

# %% [markdown]
# #2.1.1 Cabled Continental Margin Oregon Slope Base Shallow Profiler Mooring - 200m Platform
#
# 2019-07-16   -  2019-07-17
#
# SSS=Slope summer shallow

# %%
SSS=pd.read_csv("Slope_summer_shallow.csv")

# %%
A5=SSS.seawater_pressure
AA5=SSS.time
B5=SSS.seawater_temperature
C5=SSS.practical_salinity
z5=(A5*10000)/(10009.81)

# %%
ssp5=1449.2+(4.6*B5)-(0.055*B5**2)+(0.00029*B5**3)+(1.34-0.01*B5)*(C5-35)+(0.016*z5)
x5=ssp5
y5=z5
s5=max(ssp5)
print("the max speed of sound is ",s5, "m/s")
# Out:
# the max speed of sound is  1512.1948711367797 m/s

# %%
Avg5=np.polyfit(z5,ssp5,5)
Avg_ssp5=np.poly1d(Avg5)(z5)
plt.plot(ssp5,z5)
plt.plot(Avg_ssp5,z5)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('slope summer shallow')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time5=[]
for i in range(len(AA5)):
 time5.append(ntp_seconds_to_datetime(AA5[i]))

plt.plot(time5,z5)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Slope Summer Shallow')
plt.xticks(rotation=50)




#counting the bumber of dives
def getnumberofDives(z5):
    bottom=max(z5)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z5)):
        
        if(z5[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z5[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N5=getnumberofDives(z5)
print("The number of dives for Slope Summer Shallow is = ",N5)
# Out:
# The number of dives for Slope Summer Shallow is =  6

# %% [markdown]
# ======================================================================================================

# %% [markdown]
# #2.1.2 Cabled Continental Margin Oregon Slope Base Shallow Profiler Mooring - 200m Platform
#
# 2019-01-06   -  2019-01-07
#
# SWS=Slope winter shallow

# %%
SWS=pd.read_csv("Slope_winter_shallow.csv")

# %%
A6=SWS.seawater_pressure
AA6=SWS.time
B6=SWS.seawater_temperature
C6=SWS.practical_salinity
z6=(A6*10000)/(1000*9.81)

# %%
ssp6=1449.2+(4.6*B6)-(0.055*B6**2)+(0.00029*B6**3)+(1.34-0.01*B6)*(C6-35)+(0.016*z6)
x6=ssp6
y6=z6
s6=max(ssp6)
print("the max speed of sound is ",s6, "m/s")
# Out:
# the max speed of sound is  1492.3342718780652 m/s

# %%
Avg6=np.polyfit(z6,ssp6,4)
Avg_ssp6=np.poly1d(Avg6)(z6)
plt.plot(ssp6,z6)
plt.plot(Avg_ssp6,z6)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('Slope winter shallow')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time6=[]
for i in range(len(AA6)):
 time6.append(ntp_seconds_to_datetime(AA6[i]))

plt.plot(time6,z6)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Slope Winter Shallow')
plt.xticks(rotation=50)




#counting the bumber of dives
def getnumberofDives(z6):
    bottom=max(z6)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z6)):
        
        if(z6[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z6[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N6=getnumberofDives(z6)
print("The number of dives for Slope Winter Shallow is = ",N6)
# Out:
# The number of dives for Slope Winter Shallow is =  6

# %%
plt.plot(time6,ssp6)

plt.ylabel('ssp [m/s]')
plt.xlabel('Time')
plt.title('Slope Winter Shallow')
plt.xticks(rotation=50)
# Out:
# (array([737065.75      , 737065.83333333, 737065.91666667, 737066.        ,
#         737066.08333333, 737066.16666667, 737066.25      , 737066.33333333,
#         737066.41666667, 737066.5       ]),
#  <a list of 10 Text xticklabel objects>)

# %% [markdown]
# ==============================================================================================================

# %% [markdown]
# #2.2.1 Cabled Continental Margin Oregon Slope Base Deep Profiler Mooring - Wire-Following Profiler
#
# 2019-07-07   -  2019-07-08
#
# SSD=slope summer deep

# %%
SSD=pd.read_csv("Slope_summer_deep.csv")

# %%
A7=SSD.pressure
AA7=SSD.time
B7=SSD.temp
C7=SSD.practical_salinity
z7=(A7*10000)/(1000*9.81)

# %%
ssp7=1449.2+(4.6*B7)-(0.055*B7**2)+(0.00029*B7**3)+(1.34-0.01*B7)*(C7-35)+(0.016*z7)
x7=ssp7
y7=z7
s7=max(ssp7)
print("the max speed of sound is ",s7, "m/s")
# Out:
# the max speed of sound is  1504.3826589322339 m/s

# %%
Avg7=np.polyfit(z7,ssp7,5)
Avg_ssp7=np.poly1d(Avg7)(z7)
plt.plot(ssp7,z7)
plt.plot(Avg_ssp7,z7)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('Slope summer deep')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time7=[]
for i in range(len(AA7)):
 time7.append(ntp_seconds_to_datetime(AA7[i]))

plt.plot(time7,z7)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Slope Summer Deep')
plt.xticks(rotation=50)


#counting the bumber of dives
def getnumberofDives(z7):
    bottom=max(z7)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z7)):
        
        if(z7[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z7[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N7=getnumberofDives(z7)
print("The number of dives for Slope Summer Deep is = ",N7)
# Out:
# The number of dives for Slope Summer Deep is =  2

# %%
plt.plot(time7,ssp7)

plt.ylabel('ssp [m/s]')
plt.xlabel('Time')
plt.title('Slope Summer Deep')
plt.xticks(rotation=50)
# Out:
# (array([737247.        , 737247.08333333, 737247.16666667, 737247.25      ,
#         737247.33333333, 737247.41666667, 737247.5       , 737247.58333333,
#         737247.66666667]), <a list of 9 Text xticklabel objects>)

# %%
# Out:
# The number of dives for Slope Summer Deep is =  2

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# #2.2.2 Cabled Continental Margin Oregon Slope Base Deep Profiler Mooring - Wire-Following Profiler
#
# 2019-01-14  -  2019-01-15
#
# SWD= slope winter deep

# %%
SWD=pd.read_csv("Slope_winter_deep.csv")

# %%
A8=SWD.pressure
AA8=SWD.time
B8=SWD.temp
C8=SWD.practical_salinity
z8=(A8*10000)/(1000*9.81)

# %%
ssp8=1449.2+(4.6*B8)-(0.055*B8**2)+(0.00029*B8**3)+(1.34-0.01*B8)*(C8-35)+(0.016*z8)
x8=ssp8
y8=z8
s8=max(ssp8)
print("the max speed of sound is ",s8, "m/s")
# Out:
# the max speed of sound is  1504.2662508698352 m/s

# %%
Avg8=np.polyfit(z8,ssp8,5)
Avg_ssp8=np.poly1d(Avg8)(z8)
plt.plot(ssp8,z8)
plt.plot(Avg_ssp8,z8)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('Slope winter deep')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time8=[]
for i in range(len(AA8)):
 time8.append(ntp_seconds_to_datetime(AA8[i]))

plt.plot(time8,z8)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Slope Winter Deep')
plt.xticks(rotation=50)



#counting the bumber of dives
def getnumberofDives(z8):
    bottom=max(z8)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z8)):
        
        if(z8[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z8[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N8=getnumberofDives(z8)
print("The number of dives for Slope Winter Deep is = ",N8)
# Out:
# The number of dives for Slope Winter Deep is =  0

# %%
plt.plot(time8,ssp8)

plt.ylabel('ssp [m/s]')
plt.xlabel('Time')
plt.title('Slope Winter Deep')
plt.xticks(rotation=50)
# Out:
# (array([735977.5  , 735977.625, 735977.75 , 735977.875, 735978.   ,
#         735978.125, 735978.25 , 735978.375, 735978.5  ]),
#  <a list of 9 Text xticklabel objects>)

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# #3.1.1 Coastal Endurance Oregon Offshore Cabled Shallow Profiler Mooring - 200m Platform
#
# 2019-07-16 -  2019-07-17
#
# OSS= offshore summer shallow

# %%
OSS=pd.read_csv("Offshore_summer_shallow.csv")

# %%
A9=OSS.seawater_pressure
AA9=OSS.time
B9=OSS.seawater_temperature
C9=OSS.practical_salinity
z9=(A9*10000)/(1000*9.81)

# %%
ssp9=1449.2+(4.6*B9)-(0.055*B9**2)+(0.00029*B9**3)+(1.34-0.01*B9)*(C9-35)+(0.016*z9)
x9=ssp9
y9=z9
s9=max(ssp9)
print("the max speed of sound is ",s9, "m/s")
# Out:
# the max speed of sound is  1512.3208171966664 m/s

# %%
Avg9=np.polyfit(z9,ssp9,5)
Avg_ssp9=np.poly1d(Avg9)(z9)
plt.plot(ssp9,z9)
plt.plot(Avg_ssp9,z9)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('Offshore summer shallow')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time9=[]
for i in range(len(AA9)):
 time9.append(ntp_seconds_to_datetime(AA9[i]))

plt.plot(time9,z9)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Offshore Summer Shallow')
plt.xticks(rotation=50)

#counting the bumber of dives
def getnumberofDives(z9):
    bottom=max(z9)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z9)):
        
        if(z9[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z9[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N9=getnumberofDives(z9)
print("The number of dives for Offshore Summer Shallow is = ",N9)
# Out:
# The number of dives for Offshore Summer Shallow is =  6

# %%
plt.plot(time9,ssp9)

plt.ylabel('ssp [m/s]')
plt.xlabel('Time')
plt.title('Offshore Summer Shallow')
plt.xticks(rotation=50)
# Out:
# (array([737256.83333333, 737256.91666667, 737257.        , 737257.08333333,
#         737257.16666667, 737257.25      , 737257.33333333, 737257.41666667,
#         737257.5       ]), <a list of 9 Text xticklabel objects>)

# %% [markdown]
# =========================================================================================================

# %% [markdown]
# #3.1.2 Coastal Endurance Oregon Offshore Cabled Shallow Profiler Mooring - 200m Platform
#
# 2019-01-15  -  2019-01-16
#
# OWS= offshore winter shallow

# %%
OWS=pd.read_csv("Offshore_winter_shallow.csv")

# %%
A10=OWS.seawater_pressure
AA10=OWS.time
B10=OWS.seawater_temperature
C10=OWS.practical_salinity
z10=(A10*10000)/(1000*9.81)

# %%
ssp10=1449.2+(4.6*B10)-(0.055*B10**2)+(0.00029*B10**3)+(1.34-0.01*B10)*(C10-35)+(0.016*z10)
x10=ssp10
y10=z10
s10=max(ssp10)
print("the max speed of sound is ",s10, "m/s")
# Out:
# the max speed of sound is  1493.258195997046 m/s

# %%
Avg10=np.polyfit(z10,ssp10,5)
Avg_ssp10=np.poly1d(Avg10)(z10)
plt.plot(ssp10,z10)
plt.plot(Avg_ssp10,z10)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('Offshore winter shallow')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time10=[]
for i in range(len(AA10)):
 time10.append(ntp_seconds_to_datetime(AA10[i]))

plt.plot(time10,z10)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Offshore Winter Shallow')
plt.xticks(rotation=50)


#counting the bumber of dives
def getnumberofDives(z10):
    bottom=max(z10)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z10)):
        
        if(z10[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z10[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N10=getnumberofDives(z10)
print("The number of dives for Offshore Winter Shallow is = ",N10)
# Out:
# The number of dives for Offshore Winter Shallow is =  6

# %%
plt.plot(time10,ssp10)

plt.ylabel('ssp [m/s]')
plt.xlabel('Time')
plt.title('Offshore Winter Shallow')
plt.xticks(rotation=50)
# Out:
# (array([737074.83333333, 737074.91666667, 737075.        , 737075.08333333,
#         737075.16666667, 737075.25      , 737075.33333333, 737075.41666667,
#         737075.5       ]), <a list of 9 Text xticklabel objects>)

# %% [markdown]
# ==========================================================================================================

# %% [markdown]
# #3.2.1  Coastal Endurance Oregon Offshore Cabled Deep Profiler Mooring - Wire-Following Profiler
#
#
# 2019-07-10  -  2019-07-11
#
# OSD= offshore summer deep

# %%
OSD=pd.read_csv("Offshore_summer_deep.csv")

# %%
A11=OSD.pressure
AA11=OSD.time
B11=OSD.temp
C11=OSD.practical_salinity
z11=(A11*10000)/(1000*9.81)

# %%
ssp11=1449.2+(4.6*B11)-(0.055*B11**2)+(0.00029*B11**3)+(1.34-0.01*B11)*(C11-35)+(0.016*z11)
x11=ssp11
y11=z11
s11=max(ssp11)
print("the max speed of sound is ",s11, "m/s")
# Out:
# the max speed of sound is  1484.4679109229542 m/s

# %%
Avg11=np.polyfit(z11,ssp11,5)
Avg_ssp11=np.poly1d(Avg11)(z11)
plt.plot(ssp11,z11)
plt.plot(Avg_ssp11,z11)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('Offshore summer deep')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time11=[]
for i in range(len(AA11)):
 time11.append(ntp_seconds_to_datetime(AA11[i]))

plt.plot(time11,z11)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Offshore Summer Deep')
plt.xticks(rotation=50)



#counting the bumber of dives
def getnumberofDives(z11):
    bottom=max(z11)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z11)):
        
        if(z11[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z11[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N11=getnumberofDives(z11)
print("The number of dives for Offshore Summer Deep is = ",N11)
# Out:
# The number of dives for Offshore Summer Deep is =  2

# %%
plt.plot(time11,ssp11)

plt.ylabel('ssp [m/s]')
plt.xlabel('Time')
plt.title('Offshore Summer Deep')
plt.xticks(rotation=50)
# Out:
# (array([737250.875, 737251.   , 737251.125, 737251.25 , 737251.375,
#         737251.5  , 737251.625, 737251.75 , 737251.875]),
#  <a list of 9 Text xticklabel objects>)

# %% [markdown]
# ===========================================================================================================

# %% [markdown]
# #3.2.2 Coastal Endurance Oregon Offshore Cabled Deep Profiler Mooring - Wire-Following Profiler
#
# 2019-12-16   -  2019-12-17
#
# OWD= offshore winter deep

# %%
OWD=pd.read_csv("Offshore_winter_deep.csv")

# %%
A12=OWD.pressure
AA12=OWD.time
B12=OWD.temp
C12=OWD.practical_salinity
z12=(A12*10000)/(1000*9.81)

# %%
ssp12=1449.2+(4.6*B12)-(0.055*B12**2)+(0.00029*B12**3)+(1.34-0.01*B12)*(C12-35)+(0.016*z12)
x12=ssp12
y12=z12
s12=max(ssp1)
print("the max speed of sound is ",s12, "m/s")
# Out:
# the max speed of sound is  1507.3063881255669 m/s

# %%
Avg12=np.polyfit(z12,ssp12,5)
Avg_ssp12=np.poly1d(Avg12)(z12)
plt.plot(ssp12,z12)
plt.plot(Avg_ssp12,z12)
plt.gca().invert_yaxis()
plt.xlabel('ssp [m/s]')
plt.ylabel('depth [m]')
plt.title('Offshore winter deep')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
# utc to pst
ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()
def ntp_seconds_to_datetime(ntp_seconds):
    return datetime.datetime.utcfromtimestamp(ntp_seconds - ntp_delta).replace(microsecond=0)

time12=[]
for i in range(len(AA12)):
 time12.append(ntp_seconds_to_datetime(AA12[i]))

plt.plot(time12,z12)
plt.gca().invert_yaxis()
plt.ylabel('depth [m]')
plt.xlabel('Time')
plt.title('Offshore Winter Deep')
plt.xticks(rotation=50)


#counting the bumber of dives
def getnumberofDives(z12):
    bottom=max(z12)
    atbottom=False
    divecount=0
    
    for i in range(0,len(z12)):
        
        if(z12[i]>0.95*bottom and not atbottom):
            atbottom=True
        
        if(z12[i]<0.95*bottom and atbottom):
            atbottom=False
            divecount+=1
    return divecount
N12=getnumberofDives(z12)
print("The number of dives for Offshore Winter Deep is = ",N12)
# Out:
# The number of dives for Offshore Winter Deep is =  12

# %%
plt.plot(time12,ssp12)

plt.ylabel('ssp [m/s]')
plt.xlabel('Time')
plt.title('Offshore Winter Deep')
plt.xticks(rotation=50)
# Out:
# (array([735948.   , 735948.125, 735948.25 , 735948.375, 735948.5  ,
#         735948.625, 735948.75 , 735948.875, 735949.   ]),
#  <a list of 9 Text xticklabel objects>)
