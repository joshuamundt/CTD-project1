# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np

# %% [markdown]
# SS=summer shallow;
# WS=winter shallow

# %%
SS=pd.read_csv("summershallow_B3.csv")
WS=pd.read_csv("wintershallow_B3.csv")

# %% [markdown]
# SD=summer deep ; WD= winter deep

# %%
SD=pd.read_csv("summerdeep_B1.csv")
WD=pd.read_csv("winterdeep_B1.csv")

# %% [markdown]
# summer shallow

# %%
A=SS.pressure
A1=SS.time
B=SS.seawater_temperature
C=SS.practical_salinity

# %% [markdown]
# z=depth [m]; z=h=P/(rho*g)

# %%
z=A/(1000*9.81)

# %% [markdown]
# winter shallow

# %%
D=WS.pressure
D2=WS.time
E=WS.seawater_temperature
F=WS.practical_salinity

# %%
z1=D/(1000*9.81)

# %% [markdown]
# summer deep

# %%
G=SD.pressure
G2=SD.time
H=SD.temp
I=SD.practical_salinity

# %%
z2=G

# %% [markdown]
# winter deep

# %%
J=WD.pressure
J2=WD.time
K=WD.temp
L=WD.practical_salinity

# %%
z3=J

# %%
ssp=1449.2+(4.6*B)-(0.055*B**2)+(0.00029*B**3)+(1.34-0.01*B)*(C-35)+(0.016*z)
sspmean=np.mean(ssp)
x=sspmean
y=max(ssp)
print(x)
print(y)
# Out:
# 1484.6978768265533
# 1508.0598231456947

# %%
x=plt.plot(z,ssp)
plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('Summer Shallow')
y=plt.axhline(y=sspmean, color='r', linestyle='-')
plt.gca().legend(('ssp [m/s]','ssp average [m/s]'))
plt.show()

# %%
plt.plot(A1,z)
plt.ylabel('depth [m]')
plt.xlabel('time [s]')
plt.title('Summer Shallow')
# Out:
# Text(0.5, 1.0, 'Summer Shallow')

# %%
plt.plot(A1,ssp)
plt.ylabel('ssp [m/s]')
plt.xlabel('time [s]')
plt.title('Summer Shallow')
# Out:
# Text(0.5, 1.0, 'Summer Shallow')

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %%
ssp1=1449.2+(4.6*E)-(0.055*E**2)+(0.00029*E**3)+(1.34-0.01*E)*(F-35)+(0.016*z1)
ssp1mean=np.mean(ssp1)
a=sspmean
b=max(ssp1)
print(a)
print(b)
# Out:
# 1484.6978768265533
# 1493.2468771917565

# %%
plt.plot(z1,ssp1)
plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('Winter Shallow')
plt.axhline(y=ssp1mean, color='r', linestyle='-')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
plt.plot(D2,z1)
plt.ylabel('depth [m]')
plt.xlabel('time [s]')
plt.title('Winter Shallow')
# Out:
# Text(0.5, 1.0, 'Winter Shallow')

# %%
plt.plot(D2,ssp1)
plt.ylabel('ssp [m/s]')
plt.xlabel('time [s]')
plt.title('Winter Shallow')
# Out:
# Text(0.5, 1.0, 'Winter Shallow')

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %%
ssp2=1449.2+(4.6*H)-(0.055*H**2)+(0.00029*H**3)+(1.34-0.01*H)*(I-35)+(0.016*z2)
ssp2mean=np.mean(ssp2)
c=sspmean
d=max(ssp2)
print(c)
print(d)
# Out:
# 1484.6978768265533
# 1499.0492690924607

# %%
plt.plot(z2,ssp2)
plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('Summer Deep')
plt.axhline(y=ssp2mean, color='r', linestyle='-')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
plt.plot(G2,z2)
plt.ylabel('depth [m]')
plt.xlabel('time [s]')
plt.title('Summer Deep')
# Out:
# Text(0.5, 1.0, 'Summer Deep')

# %%
plt.plot(G2,ssp2)
plt.ylabel('ssp [m/s]')
plt.xlabel('time [s]')
plt.title('Summer Deep')
# Out:
# Text(0.5, 1.0, 'Summer Deep')

# %% [markdown]
# -----------------------------------------------------------------------------------------

# %%
ssp3=1449.2+(4.6*K)-(0.055*K**2)+(0.00029*K**3)+(1.34-0.01*K)*(L-35)+(0.016*z3)
ssp3mean=np.mean(ssp3)
e=sspmean
f=max(ssp3)
print(e)
print(f)
# Out:
# 1484.6978768265533
# 1499.1872843112224

# %%
plt.plot(z3,ssp3)
plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('Winter Deep')
plt.axhline(y=ssp3mean, color='r', linestyle='-')
plt.gca().legend(('ssp [m/s]','average ssp [m/s]'))
plt.show()

# %%
plt.plot(J2,z3)
plt.ylabel('depth [m]')
plt.xlabel('time [s]')
plt.title('Winter Deep')
# Out:
# Text(0.5, 1.0, 'Winter Deep')

# %%
plt.plot(J2,ssp3)
plt.ylabel('ssp [m/s]')
plt.xlabel('time [s]')
plt.title('Winter Deep)')
# Out:
# Text(0.5, 1.0, 'Winter Deep)')
